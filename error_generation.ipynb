# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv("airflow/data/job.csv")
df_original = df.copy()

print("Loaded dataset. Shape:", df.shape)
df.head()
# Out:
# Loaded dataset. Shape: (19158, 14)
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target
# 0              36       1
# 1              47       0
# 2              83       0
# 3              52       1
# 4               8       0

# %%
ERROR_RATE = 0.15   # identical to split_dataset.py

def inject_errors_job_dataset(df_chunk):
    """
    Inject realistic bad rows for the JOB dataset.
    Bad rows CAN contain NaN / inf / wrong types.
    Good rows remain clean.
    """
    df = df_chunk.copy()
    n = len(df)

    if n == 0:
        return df, []

    rows_to_corrupt = random.sample(range(n), max(1, int(n * ERROR_RATE)))
    errors_log = []

    for idx in rows_to_corrupt:
        error_type = random.choice([
            "nan_value",
            "inf_value",
            "bad_gender",
            "bad_experience",
            "negative_hours",
            "string_in_numeric",
            "huge_outlier",
        ])

        # ERROR 1 — Introduce NaN
        if error_type == "nan_value":
            col = random.choice(["city_development_index", "training_hours"])
            if col in df.columns:
                df.loc[idx, col] = np.nan
                errors_log.append((idx, error_type, col, "Inserted NaN"))

        # ERROR 2 — Introduce INF
        elif error_type == "inf_value":
            col = random.choice(["city_development_index", "training_hours"])
            if col in df.columns:
                df.loc[idx, col] = np.inf
                errors_log.append((idx, error_type, col, "Inserted INF"))

        # ERROR 3 — Invalid gender
        elif error_type == "bad_gender":
            if "gender" in df.columns:
                df.loc[idx, "gender"] = "UnknownGender"
                errors_log.append((idx, error_type, "gender", "Bad gender value"))

        # ERROR 4 — Invalid relevant experience
        elif error_type == "bad_experience":
            if "relevent_experience" in df.columns:
                df.loc[idx, "relevent_experience"] = "Experience??"
                errors_log.append((idx, error_type, "relevent_experience", "Bad experience category"))

        # ERROR 5 — Negative training hours
        elif error_type == "negative_hours":
            if "training_hours" in df.columns:
                df.loc[idx, "training_hours"] = -10
                errors_log.append((idx, error_type, "training_hours", "Negative hours"))

        # ERROR 6 — String in numeric
        elif error_type == "string_in_numeric":
            if "training_hours" in df.columns:
                df.loc[idx, "training_hours"] = "wrong_value"
                errors_log.append((idx, error_type, "training_hours", "String in numeric column"))

        # ERROR 7 — Huge unrealistic outlier
        elif error_type == "huge_outlier":
            if "city_development_index" in df.columns:
                df.loc[idx, "city_development_index"] = 1000
                errors_log.append((idx, error_type, "city_development_index", "Extreme outlier"))

    return df, errors_log

# %%
df_errors, errors_log = inject_errors_job_dataset(df)

print("Injected errors into", len(errors_log), "rows.")
pd.DataFrame(errors_log, columns=["RowIndex", "ErrorType", "Column", "Description"])
# Out:
# C:\Users\Rahul Pendam\AppData\Local\Temp\ipykernel_11468\3677753321.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'wrong_value' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, "training_hours"] = "wrong_value"
# Injected errors into 2873 rows.
#       RowIndex       ErrorType                  Column  \
# 0         3588  bad_experience     relevent_experience
# 1         4187      bad_gender                  gender
# 2        19142       nan_value          training_hours
# 3         2619      bad_gender                  gender
# 4        10119       inf_value  city_development_index
# ...        ...             ...                     ...
# 2868     14100       inf_value  city_development_index
# 2869      6441    huge_outlier  city_development_index
# 2870     13787  negative_hours          training_hours
# 2871       404      bad_gender                  gender
# 2872     17154       inf_value  city_development_index
#
#                   Description
# 0     Bad experience category
# 1            Bad gender value
# 2                Inserted NaN
# 3            Bad gender value
# 4                Inserted INF
# ...                       ...
# 2868             Inserted INF
# 2869          Extreme outlier
# 2870           Negative hours
# 2871         Bad gender value
# 2872             Inserted INF
#
# [2873 rows x 4 columns]

# %%
corrupted_indices = sorted(set([row[0] for row in errors_log]))

comparison = pd.concat([
    df_original.loc[corrupted_indices].add_prefix("original_"),
    df_errors.loc[corrupted_indices].add_prefix("corrupted_")
], axis=1)

comparison.head(20)
# Out:
#      original_enrollee_id original_city  original_city_development_index  \
# 6                   28806      city_160                            0.920
# 19                  11399       city_13                            0.827
# 20                  31972      city_159                            0.843
# 38                   8612      city_103                            0.920
# 40                   2547      city_114                            0.926
# 56                  25296       city_73                            0.754
# 62                  24690       city_41                            0.827
# 63                   8433      city_100                            0.887
# 83                  25413      city_103                            0.920
# 87                  28751      city_103                            0.920
# 91                  29036       city_16                            0.910
# 101                 14672      city_173                            0.878
# 102                 18257      city_103                            0.920
# 107                 10473       city_21                            0.624
# 111                 11338      city_114                            0.926
# 112                 27963       city_98                            0.949
# 113                  8571       city_21                            0.624
# 116                 32966       city_21                            0.624
# 135                 23947      city_103                            0.920
# 144                 24796      city_103                            0.920
#
#     original_gender original_relevent_experience original_enrolled_university  \
# 6              Male      Has relevent experience                no_enrollment
# 19           Female      Has relevent experience                no_enrollment
# 20             Male      Has relevent experience                no_enrollment
# 38              NaN       No relevent experience                no_enrollment
# 40           Female      Has relevent experience             Full time course
# 56             Male      Has relevent experience             Full time course
# 62              NaN      Has relevent experience                          NaN
# 63             Male      Has relevent experience                no_enrollment
# 83             Male      Has relevent experience                no_enrollment
# 87              NaN       No relevent experience             Full time course
# 91             Male       No relevent experience                no_enrollment
# 101             NaN       No relevent experience                no_enrollment
# 102          Female      Has relevent experience                no_enrollment
# 107            Male      Has relevent experience                no_enrollment
# 111            Male      Has relevent experience                no_enrollment
# 112            Male       No relevent experience             Full time course
# 113            Male      Has relevent experience             Full time course
# 116            Male      Has relevent experience                no_enrollment
# 135             NaN       No relevent experience                no_enrollment
# 144            Male      Has relevent experience                no_enrollment
#
#     original_education_level original_major_discipline original_experience  \
# 6                High School                       NaN                   5
# 19                  Graduate                      Arts                   4
# 20                   Masters                      STEM                  11
# 38                  Graduate                      STEM                  12
# 40                   Masters                      STEM                  16
# 56                  Graduate                      STEM                   2
# 62                   Masters                      STEM                  13
# 63                   Masters                Humanities                 >20
# 83                  Graduate                      STEM                   5
# 87               High School                       NaN                   4
# 91               High School                       NaN                   3
# 101                  Masters                      STEM                 >20
# 102                 Graduate                      STEM                  11
# 107                 Graduate                      STEM                   2
# 111                 Graduate                      STEM                  10
# 112                 Graduate                      STEM                   4
# 113                 Graduate                      STEM                   2
# 116                 Graduate                      STEM                   3
# 135                      Phd                      STEM                 NaN
# 144                 Graduate                      STEM                 >20
#
#     original_company_size  ... corrupted_relevent_experience  \
# 6                   50-99  ...       Has relevent experience
# 19                    NaN  ...       Has relevent experience
# 20                100-500  ...       Has relevent experience
# 38                    NaN  ...        No relevent experience
# 40              1000-4999  ...                  Experience??
# 56                  50-99  ...       Has relevent experience
# 62                    <10  ...       Has relevent experience
# 63                100-500  ...       Has relevent experience
# 83                 Oct-49  ...       Has relevent experience
# 87                    NaN  ...        No relevent experience
# 91                    NaN  ...        No relevent experience
# 101                   NaN  ...        No relevent experience
# 102               500-999  ...       Has relevent experience
# 107                   <10  ...       Has relevent experience
# 111                   <10  ...       Has relevent experience
# 112                   NaN  ...        No relevent experience
# 113                Oct-49  ...       Has relevent experience
# 116               100-500  ...       Has relevent experience
# 135                   NaN  ...        No relevent experience
# 144             5000-9999  ...                  Experience??
#
#     corrupted_enrolled_university  corrupted_education_level  \
# 6                   no_enrollment                High School
# 19                  no_enrollment                   Graduate
# 20                  no_enrollment                    Masters
# 38                  no_enrollment                   Graduate
# 40               Full time course                    Masters
# 56               Full time course                   Graduate
# 62                            NaN                    Masters
# 63                  no_enrollment                    Masters
# 83                  no_enrollment                   Graduate
# 87               Full time course                High School
# 91                  no_enrollment                High School
# 101                 no_enrollment                    Masters
# 102                 no_enrollment                   Graduate
# 107                 no_enrollment                   Graduate
# 111                 no_enrollment                   Graduate
# 112              Full time course                   Graduate
# 113              Full time course                   Graduate
# 116                 no_enrollment                   Graduate
# 135                 no_enrollment                        Phd
# 144                 no_enrollment                   Graduate
#
#      corrupted_major_discipline  corrupted_experience corrupted_company_size  \
# 6                           NaN                     5                  50-99
# 19                         Arts                     4                    NaN
# 20                         STEM                    11                100-500
# 38                         STEM                    12                    NaN
# 40                         STEM                    16              1000-4999
# 56                         STEM                     2                  50-99
# 62                         STEM                    13                    <10
# 63                   Humanities                   >20                100-500
# 83                         STEM                     5                 Oct-49
# 87                          NaN                     4                    NaN
# 91                          NaN                     3                    NaN
# 101                        STEM                   >20                    NaN
# 102                        STEM                    11                500-999
# 107                        STEM                     2                    <10
# 111                        STEM                    10                    <10
# 112                        STEM                     4                    NaN
# 113                        STEM                     2                 Oct-49
# 116                        STEM                     3                100-500
# 135                        STEM                   NaN                    NaN
# 144                        STEM                   >20              5000-9999
#
#      corrupted_company_type corrupted_last_new_job corrupted_training_hours  \
# 6            Funded Startup                      1                      -10
# 19                      NaN                      1                    132.0
# 20                  Pvt Ltd                      1              wrong_value
# 38                      NaN                      4                     50.0
# 40            Public Sector                      2                     14.0
# 56      Early Stage Startup                      2                     52.0
# 62                      NaN                      1                     15.0
# 63                  Pvt Ltd                     >4                      inf
# 83                      NaN                      1                     27.0
# 87                      NaN                      3                     75.0
# 91                      NaN                  never                    182.0
# 101                     NaN                      1                    150.0
# 102                     NGO                     >4                     20.0
# 107                 Pvt Ltd                      2                      2.0
# 111                 Pvt Ltd                      1                     36.0
# 112                     NaN                      1                      inf
# 113                     NGO                      2                      -10
# 116                 Pvt Ltd                      2                      -10
# 135                     NaN                    NaN                     70.0
# 144                 Pvt Ltd                     >4                     15.0
#
#     corrupted_target
# 6                  0
# 19                 1
# 20                 0
# 38                 0
# 40                 0
# 56                 0
# 62                 0
# 63                 0
# 83                 0
# 87                 0
# 91                 0
# 101                0
# 102                0
# 107                1
# 111                0
# 112                1
# 113                0
# 116                1
# 135                0
# 144                0
#
# [20 rows x 28 columns]

# %%
df_errors.head(20)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# 15         6588  city_114                   0.926    Male
# 16         4167  city_103                   0.920     NaN
# 17         5764   city_21                   0.624     NaN
# 18         2156   city_21                   0.624     NaN
# 19        11399   city_13                     inf  Female
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience                 NaN        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9   Has relevent experience       no_enrollment        Graduate
# 10   No relevent experience    Full time course     High School
# 11  Has relevent experience       no_enrollment        Graduate
# 12  Has relevent experience       no_enrollment        Graduate
# 13   No relevent experience                 NaN             NaN
# 14   No relevent experience    Full time course     High School
# 15  Has relevent experience       no_enrollment        Graduate
# 16  Has relevent experience       no_enrollment        Graduate
# 17  Has relevent experience       no_enrollment        Graduate
# 18  Has relevent experience       no_enrollment        Graduate
# 19  Has relevent experience       no_enrollment        Graduate
#
#    major_discipline experience company_size    company_type last_new_job  \
# 0              STEM        >20          NaN             NaN            1
# 1              STEM         15        50-99         Pvt Ltd           >4
# 2              STEM          5          NaN             NaN        never
# 3   Business Degree         <1          NaN         Pvt Ltd        never
# 4              STEM        >20        50-99  Funded Startup            4
# 5              STEM         11          NaN             NaN            1
# 6               NaN          5        50-99  Funded Startup            1
# 7              STEM         13          <10         Pvt Ltd           >4
# 8              STEM          7        50-99         Pvt Ltd            1
# 9              STEM         17       10000+         Pvt Ltd           >4
# 10              NaN          2          NaN             NaN        never
# 11             STEM          5    5000-9999         Pvt Ltd            1
# 12             STEM        >20    1000-4999         Pvt Ltd            3
# 13              NaN          2          NaN             NaN        never
# 14              NaN          5          NaN             NaN        never
# 15             STEM         16       Oct-49         Pvt Ltd           >4
# 16             STEM          1        50-99         Pvt Ltd        never
# 17             STEM          2    5000-9999         Pvt Ltd            2
# 18             STEM          7       10000+         Pvt Ltd        never
# 19             Arts          4          NaN             NaN            1
#
#    training_hours  target
# 0            36.0       1
# 1            47.0       0
# 2            83.0       0
# 3            52.0       1
# 4             8.0       0
# 5            24.0       1
# 6             -10       0
# 7            18.0       1
# 8            46.0       1
# 9           123.0       0
# 10           32.0       1
# 11          108.0       0
# 12           23.0       0
# 13           24.0       0
# 14           26.0       0
# 15           18.0       0
# 16          106.0       0
# 17            7.0       0
# 18           23.0       1
# 19          132.0       1
